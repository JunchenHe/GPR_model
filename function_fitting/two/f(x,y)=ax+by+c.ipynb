# %%
import sys
sys.path.append(r'../../')
from get_data import Data

input_dim=(0,1,)
train_num=52
data=Data("../.././data/data.txt",input_dim,train_num)

#训练指数模型

from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets,linear_model


def func(x, a , b,c):
    return a*x[0]+b*x[1]+c

xdata=data.train.X
ydata=data.train.Y[:,0]

# 训练数据
regr = linear_model.LinearRegression()
regr.fit(xdata,ydata)
print('coefficients(b1,b2...):',regr.coef_)
print('intercept(b0):',regr.intercept_)

pre_y=[]
for x in data.test.X:
    pre_y.append([func(x,regr.coef_[0],regr.coef_[1],regr.intercept_)])
pre_y=np.array(pre_y)

err_sum=0.0
print("\n真实值\t预测值\t\t误差率")
for a,b in zip(data.test.Y , pre_y):
    err_sum+=abs(a-b)/a
    print(a,b,abs(a-b)/a)
print("平均误差率:",err_sum/data.test.Y.shape[0])
# Out:
# coefficients(b1,b2...): [-1.38862349  0.61301545]
# intercept(b0): 16.5784099683
#
# 真实值	预测值		误差率
# [ 20.8] [ 19.81433743] [ 0.04738762]
# [ 20.1] [ 21.33887816] [ 0.06163573]
# [ 16.9] [ 18.42375962] [ 0.09016329]
# [ 16.3] [ 16.63724817] [ 0.02069007]
# [ 16.4] [ 17.02467771] [ 0.0380901]
# [ 19.] [ 19.14131703] [ 0.00743774]
# [ 16.] [ 16.08415477] [ 0.00525967]
# [ 20.] [ 18.44699493] [ 0.07765025]
# [ 15.5] [ 16.652275] [ 0.07434032]
# [ 16.5] [ 16.44084847] [ 0.00358494]
# [ 19.] [ 17.54081724] [ 0.07679909]
# [ 17.] [ 16.81122111] [ 0.01110464]
# [ 17.6] [ 18.24861259] [ 0.03685299]
# [ 20.1] [ 18.78201752] [ 0.06557127]
# [ 17.9] [ 18.98995076] [ 0.0608911]
# [ 17.] [ 18.5683654] [ 0.09225679]
# [ 17.] [ 16.98784719] [ 0.00071487]
# [ 18.7] [ 18.04585211] [ 0.03498117]
# [ 19.2] [ 20.76006812] [ 0.08125355]
# 平均误差率: [ 0.04666659]

# %%
import sys
sys.path.append(r'../../')
from get_data import Data

input_dim=(0,2,)
train_num=52
data=Data("../.././data/data.txt",input_dim,train_num)

#训练指数模型

from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets,linear_model


def func(x, a , b,c):
    return a*x[0]+b*x[1]+c

xdata=data.train.X
ydata=data.train.Y[:,0]

# 训练数据
regr = linear_model.LinearRegression()
regr.fit(xdata,ydata)
print('coefficients(b1,b2...):',regr.coef_)
print('intercept(b0):',regr.intercept_)

pre_y=[]
for x in data.test.X:
    pre_y.append([func(x,regr.coef_[0],regr.coef_[1],regr.intercept_)])
pre_y=np.array(pre_y)

err_sum=0.0
print("\n真实值\t预测值\t\t误差率")
for a,b in zip(data.test.Y , pre_y):
    err_sum+=abs(a-b)/a
    print(a,b,abs(a-b)/a)
print("平均误差率:",err_sum/data.test.Y.shape[0])
# Out:
# coefficients(b1,b2...): [ 1.23736475  0.50320664]
# intercept(b0): 8.62878071901
#
# 真实值	预测值		误差率
# [ 20.8] [ 19.90460017] [ 0.04304807]
# [ 20.1] [ 19.1959805] [ 0.04497609]
# [ 16.9] [ 18.058431] [ 0.06854621]
# [ 16.3] [ 17.14441577] [ 0.05180465]
# [ 16.4] [ 18.4523138] [ 0.12514109]
# [ 19.] [ 18.7740461] [ 0.01189231]
# [ 16.] [ 16.6760767] [ 0.04225479]
# [ 20.] [ 18.78003951] [ 0.06099802]
# [ 15.5] [ 16.91777761] [ 0.09146952]
# [ 16.5] [ 17.0792607] [ 0.03510671]
# [ 19.] [ 18.40984259] [ 0.03106092]
# [ 17.] [ 18.54595271] [ 0.09093839]
# [ 17.6] [ 19.21908962] [ 0.09199373]
# [ 20.1] [ 20.43318677] [ 0.01657646]
# [ 17.9] [ 18.07987749] [ 0.01004902]
# [ 17.] [ 17.96562864] [ 0.05680168]
# [ 17.] [ 17.41706826] [ 0.02453343]
# [ 18.7] [ 19.20302134] [ 0.02689954]
# [ 19.2] [ 20.74847944] [ 0.08064997]
# 平均误差率: [ 0.05288108]

# %%
import sys
sys.path.append(r'../../')
from get_data import Data

input_dim=(1,2,)
train_num=52
data=Data("../.././data/data.txt",input_dim,train_num)

#训练指数模型

from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets,linear_model


def func(x, a , b,c):
    return a*x[0]+b*x[1]+c

xdata=data.train.X
ydata=data.train.Y[:,0]

# 训练数据
regr = linear_model.LinearRegression()
regr.fit(xdata,ydata)
print('coefficients(b1,b2...):',regr.coef_)
print('intercept(b0):',regr.intercept_)

pre_y=[]
for x in data.test.X:
    pre_y.append([func(x,regr.coef_[0],regr.coef_[1],regr.intercept_)])
pre_y=np.array(pre_y)

err_sum=0.0
print("\n真实值\t预测值\t\t误差率")
for a,b in zip(data.test.Y , pre_y):
    err_sum+=abs(a-b)/a
    print(a,b,abs(a-b)/a)
print("平均误差率:",err_sum/data.test.Y.shape[0])
# Out:
# coefficients(b1,b2...): [ 0.30839517  0.3178976 ]
# intercept(b0): 11.6241098844
#
# 真实值	预测值		误差率
# [ 20.8] [ 19.9865091] [ 0.03911014]
# [ 20.1] [ 20.28918547] [ 0.00941221]
# [ 16.9] [ 18.18379667] [ 0.0759643]
# [ 16.3] [ 16.72507015] [ 0.02607792]
# [ 16.4] [ 17.66852616] [ 0.07734916]
# [ 19.] [ 18.96570372] [ 0.00180507]
# [ 16.] [ 16.19254685] [ 0.01203418]
# [ 20.] [ 18.65696739] [ 0.06715163]
# [ 15.5] [ 16.62157466] [ 0.07235966]
# [ 16.5] [ 16.62665932] [ 0.00767632]
# [ 19.] [ 17.93800572] [ 0.05589444]
# [ 17.] [ 17.64780586] [ 0.03810623]
# [ 17.6] [ 18.78138364] [ 0.06712407]
# [ 20.1] [ 19.83995585] [ 0.01293752]
# [ 17.9] [ 18.47736382] [ 0.03225496]
# [ 17.] [ 18.20415075] [ 0.0708324]
# [ 17.] [ 17.11284046] [ 0.00663767]
# [ 18.7] [ 18.72100564] [ 0.0011233]
# [ 19.2] [ 20.92858118] [ 0.09003027]
# 平均误差率: [ 0.04020429]
