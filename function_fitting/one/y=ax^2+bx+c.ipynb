# %%
import sys
sys.path.append(r'../../')
from get_data import Data

input_dim=(0,)
train_num=52
data=Data("../.././data/data.txt",input_dim,train_num)

#训练指数模型

from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np

def func(x, a, b,c):
    return a*x**2+b*x+c


#归一化

#xdata=data.train.mean_and_std_X[:,0]
#ydata=data.train.mean_and_std_Y[:,0]
xdata=data.train.X[:,0]
ydata=data.train.Y[:,0]

print(xdata)
print(ydata)

popt, pcov = curve_fit(func, xdata, ydata,maxfev=500000)
#popt数组中，三个值分别是待求参数a,b,c
#y2 = [func(i, popt[0],popt[1],popt[2]) for i in xdata]
print("模型参数")
print(popt)

pre_y=[]
for x in data.test.X:
    pre_y.append(func(x,popt[0],popt[1],popt[2]))
pre_y=np.array(pre_y)

err_sum=0.0
print("\n真实值\t预测值\t\t误差率")
for a,b in zip(data.test.Y , pre_y):
    err_sum+=abs(a-b)/a
    print(a,b,abs(a-b)/a)
print("平均误差率:",err_sum/data.test.Y.shape[0])
# Out:
# [ 3.06  5.99  3.52  3.95  4.26  4.36  4.58  3.69  3.27  3.52  3.41  3.8
#   6.25  3.96  3.98  4.38  5.63  3.98  4.35  3.77  4.49  5.04  4.74  4.77
#   4.7   5.87  4.36  4.89  4.14  4.95  3.7   3.86  4.1   6.1   4.11  4.39
#   4.88  4.47  3.48  4.19  5.61  5.    5.11  3.03  3.76  4.96  3.71  3.56
#   3.83  3.73  4.    4.87]
# [ 13.8  20.   17.   17.   19.2  22.   21.4  16.3  15.9  17.9  14.4  19.4
#   21.2  17.8  19.   19.9  21.1  18.2  19.4  16.2  20.   23.1  19.2  21.3
#   18.6  20.5  22.6  20.4  18.   17.2  19.   16.6  19.   21.5  17.   18.5
#   21.   18.5  17.9  16.   21.9  20.5  20.   14.9  18.   20.6  15.5  16.4
#   16.   17.8  18.8  21.9]
# 模型参数
# [ -0.92806845  10.67893874  -9.5827158 ]
#
# 真实值	预测值		误差率
# [ 20.8] [ 20.06779099] [ 0.03520236]
# [ 20.1] [ 20.42911186] [ 0.01637372]
# [ 16.9] [ 18.01765296] [ 0.06613331]
# [ 16.3] [ 17.26211991] [ 0.05902576]
# [ 16.4] [ 19.99692648] [ 0.21932479]
# [ 19.] [ 19.16322411] [ 0.00859074]
# [ 16.] [ 15.13140679] [ 0.05428708]
# ...

# %%
import sys
sys.path.append(r'../../')
from get_data import Data

input_dim=(1,)
train_num=52
data=Data("../.././data/data.txt",input_dim,train_num)

#训练指数模型

from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np

def func(x, a, b,c):
    return a*x**2+b*x+c


#归一化

#xdata=data.train.mean_and_std_X[:,0]
#ydata=data.train.mean_and_std_Y[:,0]
xdata=data.train.X[:,0]
ydata=data.train.Y[:,0]

print(xdata)
print(ydata)

popt, pcov = curve_fit(func, xdata, ydata,maxfev=500000)
#popt数组中，三个值分别是待求参数a,b,c
#y2 = [func(i, popt[0],popt[1],popt[2]) for i in xdata]
print("模型参数")
print(popt)

pre_y=[]
for x in data.test.X:
    pre_y.append(func(x,popt[0],popt[1],popt[2]))
pre_y=np.array(pre_y)

err_sum=0.0
print("\n真实值\t预测值\t\t误差率")
for a,b in zip(data.test.Y , pre_y):
    err_sum+=abs(a-b)/a
    print(a,b,abs(a-b)/a)
print("平均误差率:",err_sum/data.test.Y.shape[0])
# Out:
# [  4.61  19.95   8.12  10.07  11.13  17.41  17.13   8.11   6.56   8.46
#    6.68  10.54  21.16  13.23  13.17  15.69  21.18  12.62  16.32  10.36
#   15.03  21.04  17.31  17.32  17.54  21.33  14.24  17.06  11.41  13.17
#   10.88  10.51  10.09  21.78   9.23  13.83  16.76  12.88   8.22  11.23
#   21.49  16.35  18.79   4.08   9.23  17.9    8.6    8.18   9.23  10.62
#   11.33  17.73]
# [ 13.8  20.   17.   17.   19.2  22.   21.4  16.3  15.9  17.9  14.4  19.4
#   21.2  17.8  19.   19.9  21.1  18.2  19.4  16.2  20.   23.1  19.2  21.3
#   18.6  20.5  22.6  20.4  18.   17.2  19.   16.6  19.   21.5  17.   18.5
#   21.   18.5  17.9  16.   21.9  20.5  20.   14.9  18.   20.6  15.5  16.4
#   16.   17.8  18.8  21.9]
# 模型参数
# [ -0.01342161   0.76956203  11.15328821]
#
# 真实值	预测值		误差率
# [ 20.8] [ 19.98934748] [ 0.03897368]
# [ 20.1] [ 20.8826143] [ 0.03893603]
# [ 16.9] [ 18.40593994] [ 0.08910887]
# [ 16.3] [ 16.72485435] [ 0.02606468]
# [ 16.4] [ 18.11218888] [ 0.10440176]
# ...

# %%
import sys
sys.path.append(r'../../')
from get_data import Data

input_dim=(2,)
train_num=52
data=Data("../.././data/data.txt",input_dim,train_num)

#训练指数模型

from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np

def func(x, a, b,c):
    return a*x**2+b*x+c


#归一化

#xdata=data.train.mean_and_std_X[:,0]
#ydata=data.train.mean_and_std_Y[:,0]
xdata=data.train.X[:,0]
ydata=data.train.Y[:,0]

print(xdata)
print(ydata)

popt, pcov = curve_fit(func, xdata, ydata,maxfev=500000)
#popt数组中，三个值分别是待求参数a,b,c
#y2 = [func(i, popt[0],popt[1],popt[2]) for i in xdata]
print("模型参数")
print(popt)

pre_y=[]
for x in data.test.X:
    pre_y.append(func(x,popt[0],popt[1],popt[2]))
pre_y=np.array(pre_y)

err_sum=0.0
print("\n真实值\t预测值\t\t误差率")
for a,b in zip(data.test.Y , pre_y):
    err_sum+=abs(a-b)/a
    print(a,b,abs(a-b)/a)
print("平均误差率:",err_sum/data.test.Y.shape[0])
# Out:
# [  4.8  11.1   7.8   9.    7.5  10.2   9.8   7.9   4.8   9.3   7.    8.7
#   10.2   8.1   8.6   9.8  12.5   8.2   7.6   5.9  10.2   9.8   9.3  10.8
#    9.2  10.   11.6  10.8   8.8   9.8  10.3   8.7  10.7  11.    9.2   9.8
#   13.9   9.8   7.7   8.3  13.1  12.7  12.6   7.5  11.   13.    9.1   6.8
#    7.9   7.9   9.2  11.2]
# [ 13.8  20.   17.   17.   19.2  22.   21.4  16.3  15.9  17.9  14.4  19.4
#   21.2  17.8  19.   19.9  21.1  18.2  19.4  16.2  20.   23.1  19.2  21.3
#   18.6  20.5  22.6  20.4  18.   17.2  19.   16.6  19.   21.5  17.   18.5
#   21.   18.5  17.9  16.   21.9  20.5  20.   14.9  18.   20.6  15.5  16.4
#   16.   17.8  18.8  21.9]
# 模型参数
# [-0.03932836  1.58572129  7.4485237 ]
#
# 真实值	预测值		误差率
# [ 20.8] [ 20.06028293] [ 0.03556332]
# [ 20.1] [ 18.53441789] [ 0.07788966]
# [ 16.9] [ 18.62180568] [ 0.10188199]
# [ 16.3] [ 17.42441214] [ 0.06898234]
# [ 16.4] [ 17.71253223] [ 0.08003245]
# [ 19.] [ 19.04694613] [ 0.00247085]
# [ 16.] [ 17.71253223] [ 0.10703326]
# ...
